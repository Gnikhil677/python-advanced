# %%
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt 

dataframe = load_dataset('lukebarousse/data_jobs')

df = dataframe['train'].to_pandas()

df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

import ast

df['job_skills'] = df['job_skills'].apply(lambda x: ast.literal_eval(x) if pd.notna(x) else x)
# Out:
# Using the latest cached version of the dataset since lukebarousse/data_jobs couldn't be found on the Hugging Face Hub
# Found the latest cached dataset configuration 'default' at C:\Users\gnikh\.cache\huggingface\datasets\lukebarousse___data_jobs\default\0.0.0\1d815e9ce232eb27db11939c44eb048fe6d2e9ab (last modified on Sat Jan 25 12:41:59 2025).

# %%
df_us = df[df['job_country']=='United States'].dropna(subset='salary_year_avg').copy()

data = df_us['job_title_short'].value_counts().index[:6].tolist()

data
# Out:
# ['Data Scientist',
#  'Data Analyst',
#  'Data Engineer',
#  'Senior Data Scientist',
#  'Senior Data Engineer',
#  'Senior Data Analyst']

# %%
top6df = df_us[df_us['job_title_short'].isin(data)]

top6df
# Out:
#        job_title_short                                          job_title  \
# 92       Data Engineer            Remote - Data Engineer - Permanent - W2
# 100     Data Scientist            Data Scientist, Risk Data Mining - USDS
# 109       Data Analyst              Senior Supply Chain Analytics Analyst
# 116     Data Scientist                                     Data Scientist
# 146      Data Engineer  Data Engineer Graduate (Real Time Communicatio...
# ...                ...                                                ...
# 785563  Data Scientist  Data Scientist I/II (Model Risk Management & M...
# 785624   Data Engineer                   Data Analytics Engineer (Hybrid)
# 785641   Data Engineer                                      Data Engineer
# 785648  Data Scientist  Director Data Scientist - Commercial Platforms...
# 785692  Data Scientist               Data Scientist- Hybrid Work Location
#
#              job_location                                    job_via  \
# ...

# %%
import seaborn as sns

# %%
order = top6df.groupby('job_title_short')['salary_year_avg'].median().sort_values(ascending=False).index.tolist()

order
# Out:
# ['Senior Data Scientist',
#  'Senior Data Engineer',
#  'Data Scientist',
#  'Data Engineer',
#  'Senior Data Analyst',
#  'Data Analyst']

# %%
sns.boxplot(data=top6df, x='salary_year_avg', y='job_title_short', order= order)
sns.set_theme(style='ticks')

plt.title('Salary Distribution of data jobs in US')
plt.ylabel('')
plt.xlim(0,650000)
ax = plt.gca()
ax.xaxis.set_major_formatter(plt.FuncFormatter(lambda x, pos: f'${int(x/1000)}K'))
