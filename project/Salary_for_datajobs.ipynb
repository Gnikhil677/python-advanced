# %%
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt 

dataframe = load_dataset('lukebarousse/data_jobs')

df = dataframe['train'].to_pandas()

df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

import ast

df['job_skills'] = df['job_skills'].apply(lambda x: ast.literal_eval(x) if pd.notna(x) else x)

# %%
df_in = df[df['job_country']=='India'].dropna(subset='salary_year_avg').copy()

data = df_in['job_title_short'].value_counts().index[:6].tolist()

data
# Out:
# ['Data Engineer',
#  'Data Analyst',
#  'Data Scientist',
#  'Machine Learning Engineer',
#  'Senior Data Engineer',
#  'Software Engineer']

# %%
top6df = df_in[df_in['job_title_short'].isin(data)]

top6df
# Out:
#                   job_title_short  \
# 1209    Machine Learning Engineer
# 2022                Data Engineer
# 2785                Data Engineer
# 3190         Senior Data Engineer
# 3930               Data Scientist
# ...                           ...
# 781857       Senior Data Engineer
# 784033               Data Analyst
# 784768             Data Scientist
# 785395              Data Engineer
# 785515               Data Analyst
#
#                                                 job_title  \
# 1209                      Computer Vision Developer (R&D)
# 2022                       Data Engineer - SQL (Power BI)
# 2785    Staff Software Engineer - Data Engineering (Ja...
# 3190         Senior Big Data DevOps & Deployment Engineer
# 3930                                  Lead Data Scientist
# ...                                                   ...
# 781857                               Senior Data Engineer
# 784033                           Recruitment Data Analyst
# ...

# %%
import seaborn as sns

# %%
order = top6df.groupby('job_title_short')['salary_year_avg'].median().sort_values(ascending=False).index.tolist()

order
# Out:
# ['Data Engineer',
#  'Senior Data Engineer',
#  'Data Scientist',
#  'Data Analyst',
#  'Machine Learning Engineer',
#  'Software Engineer']

# %%
sns.boxplot(data=top6df, x='salary_year_avg', y='job_title_short', order= order)
sns.set_theme(style='ticks')

plt.title('Salary Distribution of data jobs in INDIA')
plt.xlabel('Yearly Salary')
plt.ylabel('')
plt.xlim(0,300000)
ax = plt.gca()
ax.xaxis.set_major_formatter(plt.FuncFormatter(lambda x, pos: f'${int(x/1000)}K'))
