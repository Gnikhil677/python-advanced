# %%
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt 

dataframe = load_dataset('lukebarousse/data_jobs')

df = dataframe['train'].to_pandas()

df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

import ast

df['job_skills'] = df['job_skills'].apply(lambda x: ast.literal_eval(x) if pd.notna(x) else x)

# %%
da_in = df[(df['job_title_short']=='Data Analyst') & (df['job_country']=='India')].copy()

# %%
da_in['month_no'] = da_in['job_posted_date'].dt.month

# %%
exploded_df = da_in.explode('job_skills')

# %%
pivot_da = exploded_df.pivot_table(index='month_no', columns='job_skills', aggfunc='size', fill_value=0)

pivot_da.loc['Total'] = pivot_da.sum()

sorted_da = pivot_da[pivot_da.loc['Total'].sort_values(ascending=False).index]

sorted_da
# Out:
# job_skills   sql  python  excel  tableau  power bi    r  sas  azure  aws  \
# month_no
# 1            305     216    218      159        98   89  128     46   32
# 2            209     148    156      116        75   67   82     26   33
# 3            229     151    138      125        76   58   62     45   38
# 4            204     143    138       98        83   56   52     40   31
# 5            155     101    106       71        61   42   30     33   22
# 6            193     150    115      114        77   76   74     37   32
# 7            245     161    174      124        93   67   78     39   31
# 8            317     216    192      152       127  112   98     52   63
# 9            341     229    228      195       168  100   92     35   41
# 10           269     185    193      153       110   95   86     47   48
# 11           359     264    242      182       156  115   70     57   51
# 12           333     239    217      178       162  114  100     55   30
# ...

# %%
totals = da_in.groupby('month_no').size()

# %%
toplot = sorted_da.div(totals/100, axis=0)

toplot = toplot.drop('Total')

toplot
# Out:
# job_skills        sql     python      excel    tableau   power bi          r  \
# month_no
# 1           48.566879  34.394904  34.713376  25.318471  15.605096  14.171975
# 2           48.267898  34.180139  36.027714  26.789838  17.321016  15.473441
# 3           54.265403  35.781991  32.701422  29.620853  18.009479  13.744076
# 4           48.803828  34.210526  33.014354  23.444976  19.856459  13.397129
# 5           55.755396  36.330935  38.129496  25.539568  21.942446  15.107914
# 6           52.588556  40.871935  31.335150  31.062670  20.980926  20.708447
# 7           53.610503  35.229759  38.074398  27.133479  20.350109  14.660832
# 8           51.294498  34.951456  31.067961  24.595469  20.550162  18.122977
# 9           54.126984  36.349206  36.190476  30.952381  26.666667  15.873016
# 10          53.800000  37.000000  38.600000  30.600000  22.000000  19.000000
# 11          49.722992  36.565097  33.518006  25.207756  21.606648  15.927978
# ...

# %%
toplot = toplot.reset_index()

# %%
toplot['Month'] = toplot['month_no'].apply(lambda x : pd.to_datetime(str(x), format='%m').strftime('%b'))

# %%
toplot = toplot.set_index('Month')

toplot
# Out:
# job_skills  month_no        sql     python      excel    tableau   power bi  \
# Month
# Jan                1  48.566879  34.394904  34.713376  25.318471  15.605096
# Feb                2  48.267898  34.180139  36.027714  26.789838  17.321016
# Mar                3  54.265403  35.781991  32.701422  29.620853  18.009479
# Apr                4  48.803828  34.210526  33.014354  23.444976  19.856459
# May                5  55.755396  36.330935  38.129496  25.539568  21.942446
# Jun                6  52.588556  40.871935  31.335150  31.062670  20.980926
# Jul                7  53.610503  35.229759  38.074398  27.133479  20.350109
# Aug                8  51.294498  34.951456  31.067961  24.595469  20.550162
# Sep                9  54.126984  36.349206  36.190476  30.952381  26.666667
# Oct               10  53.800000  37.000000  38.600000  30.600000  22.000000
# Nov               11  49.722992  36.565097  33.518006  25.207756  21.606648
# ...

# %%
toplot = toplot.drop(columns='month_no')

toplot
# Out:
# job_skills        sql     python      excel    tableau   power bi          r  \
# Month
# Jan         48.566879  34.394904  34.713376  25.318471  15.605096  14.171975
# Feb         48.267898  34.180139  36.027714  26.789838  17.321016  15.473441
# Mar         54.265403  35.781991  32.701422  29.620853  18.009479  13.744076
# Apr         48.803828  34.210526  33.014354  23.444976  19.856459  13.397129
# May         55.755396  36.330935  38.129496  25.539568  21.942446  15.107914
# Jun         52.588556  40.871935  31.335150  31.062670  20.980926  20.708447
# Jul         53.610503  35.229759  38.074398  27.133479  20.350109  14.660832
# Aug         51.294498  34.951456  31.067961  24.595469  20.550162  18.122977
# Sep         54.126984  36.349206  36.190476  30.952381  26.666667  15.873016
# Oct         53.800000  37.000000  38.600000  30.600000  22.000000  19.000000
# Nov         49.722992  36.565097  33.518006  25.207756  21.606648  15.927978
# ...

# %%
plot = toplot.iloc[:,:5]

plot
# Out:
# job_skills        sql     python      excel    tableau   power bi
# Month
# Jan         48.566879  34.394904  34.713376  25.318471  15.605096
# Feb         48.267898  34.180139  36.027714  26.789838  17.321016
# Mar         54.265403  35.781991  32.701422  29.620853  18.009479
# Apr         48.803828  34.210526  33.014354  23.444976  19.856459
# May         55.755396  36.330935  38.129496  25.539568  21.942446
# Jun         52.588556  40.871935  31.335150  31.062670  20.980926
# Jul         53.610503  35.229759  38.074398  27.133479  20.350109
# Aug         51.294498  34.951456  31.067961  24.595469  20.550162
# Sep         54.126984  36.349206  36.190476  30.952381  26.666667
# Oct         53.800000  37.000000  38.600000  30.600000  22.000000
# Nov         49.722992  36.565097  33.518006  25.207756  21.606648
# Dec         51.388889  36.882716  33.487654  27.469136  25.000000

# %%
import seaborn as sns

# %%
from adjustText import adjust_text

# %%
sns.lineplot(data=plot, dashes=False, palette='tab10')
sns.set_theme(style='ticks')
sns.despine()

plt.title('Skills Trend chart for Data Analysts in INDIA')
plt.xlabel('')
plt.ylabel('Percentage')
plt.legend().remove()

from matplotlib.ticker import PercentFormatter
ax = plt.gca()
ax.yaxis.set_major_formatter(PercentFormatter(decimals=0))

texts = []

for i in range(5):
    texts.append(plt.text(11.3, plot.iloc[-1, i], plot.columns[i]))

adjust_text(texts)

plt.tight_layout()
